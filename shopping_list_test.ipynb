# %%
import pygsheets

# %%
gc = pygsheets.authorize(client_secret='client_secret_420621140312-33isgppflhgnr2mltokq975qe6prd17t.apps.googleusercontent.com.json')
# Out:
# Please go to this URL and finish the authentication flow: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=420621140312-33isgppflhgnr2mltokq975qe6prd17t.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fspreadsheets+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&state=n48ExOdgrC9Nj3fnCS9tS1GVzFX6fW&prompt=consent&access_type=offline
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21644/128480552.py in <module>
# ----> 1 gc = pygsheets.authorize(client_secret='client_secret_420621140312-33isgppflhgnr2mltokq975qe6prd17t.apps.googleusercontent.com.json')
#
# ...

# %%
gc = pygsheets.authorize(client_secret='4/1AX4XfWhdoXEBc9WgBwBTM7A3b2LRgM4vESvzHualgU_sDcbcc2ea8ixa2t8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21644/1597589205.py in <module>
# ----> 1 gc = pygsheets.authorize(client_secret='4/1AX4XfWhdoXEBc9WgBwBTM7A3b2LRgM4vESvzHualgU_sDcbcc2ea8ixa2t8')
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pygsheets\authorization.py in authorize(client_secret, service_account_file, service_account_env_var, credentials_directory, scopes, custom_credentials, local, **kwargs)
#     127         credentials = service_account.Credentials.from_service_account_file(service_account_file, scopes=scopes)
#     128     else:
# --> 129         credentials = _get_user_authentication_credentials(client_secret, scopes, credentials_directory, local)
#     130
#     131     return Client(credentials, **kwargs)
#
# ...
